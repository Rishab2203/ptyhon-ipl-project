# %%
import pandas as pd
matches_df = pd.read_csv("../data/matches.csv")
deliveries_df = pd.read_csv("../data/deliveries.csv")
deliveries_df.rename(columns={"match_id":"id"},inplace=True)

df = matches_df[["id","season"]].merge(deliveries_df,on="id",how="right")
df
# Out:
#          id  season  inning                 batting_team  \
# 0         1    2017       1          Sunrisers Hyderabad
# 1         1    2017       1          Sunrisers Hyderabad
# 2         1    2017       1          Sunrisers Hyderabad
# 3         1    2017       1          Sunrisers Hyderabad
# 4         1    2017       1          Sunrisers Hyderabad
# ...     ...     ...     ...                          ...
# 150455  636    2016       2  Royal Challengers Bangalore
# 150456  636    2016       2  Royal Challengers Bangalore
# 150457  636    2016       2  Royal Challengers Bangalore
# 150458  636    2016       2  Royal Challengers Bangalore
# 150459  636    2016       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# ...

# %%
batsman_df = df[df["batsman"]=="V Kohli"].groupby("season")["batsman_runs"].mean().reset_index(name="strike rate")
batsman_df
# Out:
#    season  strike rate
# 0    2008     0.982143
# 1    2009     1.093333
# 2    2010     1.421296
# 3    2011     1.177590
# 4    2012     1.093093
# 5    2013     1.356688
# 6    2014     1.192691
# 7    2015     1.278481
# 8    2016     1.485496
# 9    2017     1.198444
